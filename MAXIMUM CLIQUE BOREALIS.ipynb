# %%
import strawberryfields as sf
import numpy as np

eng = sf.RemoteEngine("borealis")
device = eng.device

# %%
device.certificate
# Out:
# {'finished_at': '2022-09-05T17:42:39.089640+00:00',
#  'target': 'borealis',
#  'loop_phases': [-0.69, 1.427, -2.604],
#  'schmidt_number': 1.161,
#  'common_efficiency': 0.411,
#  'loop_efficiencies': [0.896, 0.893, 0.838],
#  'squeezing_parameters_mean': {'low': 0.659, 'high': 1.137, 'medium': 0.954},
#  'relative_channel_efficiencies': [0.952,
#   0.991,
#   0.967,
#   0.958,
#   0.949,
#   0.885,
#   0.912,
#   0.976,
#   0.973,
#   1.0,
#   0.904,
#   0.936,
#   0.936,
#   0.903,
#   0.971,
#   0.903]}

# %%
from strawberryfields.tdm import borealis_gbs, full_compile, get_mode_indices

gate_args_list = borealis_gbs(device, modes=216, squeezing="high")
# Out:
# WARNING:strawberryfields.tdm.utils:121/259 arguments of phase gate 1 have been shifted by pi in order to be compatible with the phase modulators.
# WARNING:strawberryfields.tdm.utils:137/259 arguments of phase gate 2 have been shifted by pi in order to be compatible with the phase modulators.

# %%
from strawberryfields.apps import data, plot, sample, clique
import numpy as np
import networkx as nx
#importing the matplotlib library for plotting the graph
import matplotlib.pyplot as plt
import time

# get the start time
st = time.time()

# main program


G= nx.erdos_renyi_graph(10,0.5)
nx.draw(G, with_labels=True)
plt.show()
pos = nx.circular_layout(G)
elist =  [(0, 3), (1, 2), (3, 1),(2,3),(1,0),(0,2)] #find edges by recursion method


# wait for 3 seconds
time.sleep(5)

# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')


nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_labels(G, pos)
nx.draw_networkx_edges(G, pos, edge_color='k', width=0.5) 
nx.draw_networkx_edges(G, pos, edgelist=elist, edge_color='b', width=2)
# Out:
# Execution time: 5.188737154006958 seconds
